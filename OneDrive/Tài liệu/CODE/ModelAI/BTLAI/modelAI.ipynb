# %%
import numpy as np #tính toán số học
import pandas as pd # xử lí dữ liệu dạng bảng
import matplotlib.pyplot as plt # vẽ đồ thị
import seaborn as sns #trực quan hóa dữ liệu mở rộng của matplotlib
import plotly.express as px # vẽ biểu đồ tròn, cột
import plotly.graph_objects as go #tùy chỉnh thành phần trên từng đồ thị
from plotly.subplots import make_subplots #tổ chức và hiển thị nhiều đồ thị trong 1 cửa sổ
import os #tương tác vs hệ thống file/tệp
import random #tạo số ngẫu nhiên
from PIL import Image, ImageEnhance, ImageOps #Xử lí ảnh
from tqdm import tqdm #thanh hiển thị trạng thái
from typing import Tuple, List, Dict, Optional
from sklearn.metrics import confusion_matrix

sns.set_style('darkgrid')

# %% [markdown]
# ĐƯỜNG DẪN DATA

# %%
TRAINING_DATA_DIR = 'C:/Users/ADMIN/OneDrive/Tài liệu/CODE/ModelAI/BTLAI/Train1'
TESTING_DATA_DIR = 'C:/Users/ADMIN/OneDrive/Tài liệu/CODE/ModelAI/BTLAI/Test'
MAX_ROWS_PER_CATEGORY = 5000

# %%
meta_data = [] #Khởi tạo danh sách lưu về thông tin từng hình ảnh

#Lặp qua 2 thư mục fire và non_fire
for subdir in ["fire", "non_fire"]: #Nhận 2 giá trị fire hay non_fire
    curr_dir = os.path.join(TRAINING_DATA_DIR, subdir) #Đường dẫn tới thư mục
    
    #Duyệt qua từng file với chỉ số index tương ứng
    for index, filename in enumerate(os.listdir(curr_dir)):
        if index >= MAX_ROWS_PER_CATEGORY:
            break
        full_path = os.path.join(curr_dir, filename) #Tạo đường dẫn đầy đủ tới file
        
        #Tải hình ảnh từ đường dẫn và lấy thông tin ảnh
        shape = Image.open(full_path).size
        height = shape[1]
        width = shape[0]
        
        #Thêm 1 danh sách vào meta_data
        meta_data.append([full_path, subdir,  height, width])
        
#Chuyển danh sách meta_data thành 1 Dataframe        
df = pd.DataFrame(meta_data, columns=['path','label', 'height', 'width'])
df = df.sample(frac=1).reset_index(drop=True) #Xáo trộn(100%) các dòng trong dataframe rồi đặt lại chỉ số
df.head(10)
# Out:
#                                                 path     label  height  width
# 0  C:/Users/ADMIN/OneDrive/Tài liệu/CODE/ModelA...      fire    3082   4623
# 1  C:/Users/ADMIN/OneDrive/Tài liệu/CODE/ModelA...      fire     600    400
# 2  C:/Users/ADMIN/OneDrive/Tài liệu/CODE/ModelA...      fire     338    600
# 3  C:/Users/ADMIN/OneDrive/Tài liệu/CODE/ModelA...      fire     720   1280
# 4  C:/Users/ADMIN/OneDrive/Tài liệu/CODE/ModelA...  non_fire     300    400
# 5  C:/Users/ADMIN/OneDrive/Tài liệu/CODE/ModelA...  non_fire     804   1280
# 6  C:/Users/ADMIN/OneDrive/Tài liệu/CODE/ModelA...  non_fire     720   1280
# 7  C:/Users/ADMIN/OneDrive/Tài liệu/CODE/ModelA...  non_fire     533    800
# 8  C:/Users/ADMIN/OneDrive/Tài liệu/CODE/ModelA...      fire     305    305
# 9  C:/Users/ADMIN/OneDrive/Tài liệu/CODE/ModelA...  non_fire     600    400

# %% [markdown]
# BIỂU DIỄN TRỰC QUAN ẢNH TRONG TẬP TRAIN

# %%
fig = make_subplots(rows=1, cols=2, specs=[[{"type": "xy"}, {"type": "pie"}]])
#Tạo 1 biểu đồ cột và 1 biểu đồ tròn

fig.add_trace(go.Bar(x =df['label'].value_counts().index, #lấy các nhãn label trên trục x
                     y=df['label'].value_counts().to_numpy(), #lấy số lượng từng nhãn tương ứng trên trục y
                     marker_color=['darkorange','green'],showlegend=False),#màu sắc mỗi cột
                     row=1,col=1)# đặt biểu đồ ở hàng 1 cột 1

fig.add_trace(go.Pie(
     values=df['label'].value_counts().to_numpy(),#Giá trị để tạo tỷ lệ trong biểu đồ tròn
     labels=df['label'].value_counts().index, #Nhãn tương ứng 
    marker=dict(colors=['darkorange','green'])),#màu sắc
    row=1, col=2)

# %% [markdown]
# HIỂN THỊ 1 SỐ ẢNH CHÁY

# %%
label = 'fire'  # Định nghĩa nhãn (label) cho ảnh có lửa
data = df[df['label'] == label]  # Lọc dữ liệu để lấy các hàng có nhãn là 'fire'
sns.set_style('dark')  # Thiết lập phong cách hiển thị của đồ thị thành 'dark'

pics = 6  # Số lượng ảnh muốn hiển thị

# Tạo một khung hình với các subplot
fig, ax = plt.subplots(int(pics / 2), 2, figsize=(15, 15))  # Tạo grid subplot (3x2) với kích thước 15x15
ax = ax.ravel()  # Chuyển mảng 2D của các axes thành mảng 1D để dễ dàng truy cập qua chỉ số

# Vòng lặp qua số lượng ảnh cần hiển thị
for i in range(int(pics / 2) * 2):  # Lặp qua tất cả các subplot
    try:
        # Lấy một đường dẫn ngẫu nhiên từ dữ liệu
        path = data.sample(1).iloc[0]['path']  # Chọn ngẫu nhiên một hàng từ dữ liệu và lấy đường dẫn ảnh
        
        img = Image.open(path)  # Mở ảnh từ đường dẫn
        
        # Chuyển ảnh thành mảng và chuẩn hóa giá trị pixel về khoảng [0, 1]
        img_array = np.array(img) / 255.0  # Chia giá trị pixel cho 255 để chuẩn hóa
        
        # Hiển thị ảnh trên subplot
        ax[i].imshow(img_array)  # Hiển thị ảnh trên trục con
        ax[i].axis('off')  # Tắt hiển thị các trục x và y
    except Exception as e:  # Xử lý ngoại lệ khi xảy ra lỗi
        print(f"Error loading image {i}: {str(e)}")  # In ra lỗi nếu không thể tải ảnh

# Thêm tiêu đề chung cho toàn bộ hình
plt.suptitle('Images with Fire', fontsize=16)  # Tiêu đề chính của hình
plt.tight_layout()  # Điều chỉnh khoảng cách giữa các subplot để tránh bị chồng chéo
plt.show()  # Hiển thị toàn bộ hình

# %% [markdown]
# TIỀN XỬ LÍ ẢNH

# %%
# RESIZE ẢNH

def process_image(path, size=(256, 256)):
    try:
        with Image.open(path) as img: #mở ảnh từ đường dẫn
            img = img.convert("RGB")  # Chuyển sang định dạng RGB
            img = ImageOps.fit(img, size, Image.Resampling.LANCZOS)  # Resize với padding
            return np.asarray(img, dtype=np.float64) / 255.0  # Chuẩn hóa pixel về khoảng [0, 1]
    except Exception as e:
        print(f"Error processing image {path}: {e}")
        return None

# Hàm tăng cường dữ liệu (augmentation)
def augment_image(image):
    try:
        # Xoay ảnh ngẫu nhiên(xoay góc ngẫu nhiên trong khoảng -25,25 độ)
        angle = random.uniform(-25, 25)
        image = image.rotate(angle, resample=Image.BICUBIC) #xoay ảnh với resample chất lượng cao

        # Dịch chuyển ảnh
        max_dx, max_dy = int(0.1 * image.size[0]), int(0.1 * image.size[1]) # Tính khoảng dịch chuyển tối đa (10% kích thước ảnh)
        dx, dy = random.randint(-max_dx, max_dx), random.randint(-max_dy, max_dy)  # Lấy ngẫu nhiên giá trị dịch chuyển
        image = image.transform(
            image.size, Image.AFFINE, (1, 0, dx, 0, 1, dy), resample=Image.BICUBIC
        ) #dịch chuyển ảnh theo ma trận biến đổi Affine

        # Cắt xiên ảnh
        shear = random.uniform(-0.05, 0.05) #hệ số xiên ngẫu nhiên
        image = image.transform(
            image.size, Image.AFFINE, (1, shear, 0, shear, 1, 0), resample=Image.BICUBIC
        )

        # Phóng to hoặc thu nhỏ
        scale = random.uniform(0.8, 1.2) #tỉ lệ phóng to/thu nhỏ
        new_size = (int(image.size[0] * scale), int(image.size[1] * scale))# tính kích thước mới
        image = image.resize(new_size, resample=Image.BICUBIC)#resize ảnh

        # Cắt hoặc padding về kích thước chuẩn
        if scale > 1:
            image = ImageOps.fit(image, image.size, Image.ANTIALIAS)
        else: #nếu ảnh bị thu nhỏ, thêm padding đen
            padded_img = Image.new("RGB", image.size, (0, 0, 0)) #tạo 1 ảnh nền đen
            padded_img.paste(image, (0, 0))#dán ảnh gốc lên ảnh nền
            image = padded_img

        # Lật ngẫu nhiên
        if random.random() < 0.5: #50% khả năng lật ngang
            image = image.transpose(Image.FLIP_LEFT_RIGHT)

        return image #trả về ảnh đã tăng cường
    except Exception as e:
        
        return image #nếu có lỗi, trả ảnh gốc


# Xây dựng dữ liệu từ DataFrame
df = pd.DataFrame({
    "path": [os.path.join(TRAINING_DATA_DIR, "fire", f) for f in os.listdir(os.path.join(TRAINING_DATA_DIR, "fire"))] +
            [os.path.join(TRAINING_DATA_DIR, "non_fire", f) for f in os.listdir(os.path.join(TRAINING_DATA_DIR, "non_fire"))],
    "label": ["fire"] * len(os.listdir(os.path.join(TRAINING_DATA_DIR, "fire"))) +
             ["non_fire"] * len(os.listdir(os.path.join(TRAINING_DATA_DIR, "non_fire")))
})

# Xử lý dữ liệu và loại bỏ ảnh bị lỗi
processed_images = []
processed_labels = []

for _, row in df.iterrows(): #lặp qua từng dòng trong dataframe
    img = process_image(row["path"]) #resize và chuẩn hóa ảnh
    if img is not None:#nếu ảnh không lỗi 
        # Tăng cường dữ liệu ngẫu nhiên cho một phần ảnh
        
        if random.random() < 0.5: # 50% ảnh sẽ được tăng cường dữ liệu
            img = augment_image(Image.fromarray((img * 255).astype(np.uint8))) #tăng cường dữ liệu
            img = img.resize((256, 256), resample=Image.Resampling.LANCZOS) #resize lại về kích thước chuẩn
            img = np.asarray(img, dtype=np.float64) / 255.0 #chuẩn hóa pixel

        processed_images.append(img) #thêm ảnh đã xử lí vào
        processed_labels.append(1 if row["label"] == "fire" else 0) #thêm nhãn


#Chuyển danh sách thành mảng numpy
X = np.array(processed_images, dtype=np.float32) 
y = np.array(processed_labels, dtype=np.float32)

# Chia dữ liệu thành tập huấn luyện và tập kiểm thử
split_index = int(0.8 * len(X))
X_train, X_val = X[:split_index], X[split_index:]
y_train, y_val = y[:split_index], y[split_index:]
print(f"So luong mau train: {len(X_train)}")
print(f"So luong mau kiem tra: {len(X_val)}")
# Out:
# So luong mau train: 1983
# So luong mau kiem tra: 496

# %% [markdown]
# XÂY DỰNG MÔ HÌNH

# %%
from typing import Tuple, List, Dict, Optional

class Layer:
    def forward(self, input_data: np.ndarray) -> np.ndarray: #tính toán đầu ra của lớp truyền
        raise NotImplementedError
        
    def backward(self, gradient: np.ndarray) -> np.ndarray: #tính gradient trong quá trình huấn luyện
        raise NotImplementedError

class Conv2D(Layer):
    def __init__(self, filters: int, kernel_size: Tuple[int, int], input_shape: Tuple[int, int, int] = None):
        self.filters = filters #số bộ lọc
        self.kernel_size = kernel_size 
        self.input_shape = input_shape
        self.kernels = None  # Trọng số sẽ được khởi tạo khi cần
        self.biases = None   # Bias sẽ được khởi tạo khi cần
        
    def initialize_weights(self, input_shape: Tuple[int, int, int]):
        """Khởi tạo trọng số và bias dựa trên input_shape."""
        channels = input_shape[-1]
        self.kernels = np.random.randn(self.filters, self.kernel_size[0], self.kernel_size[1], channels) * 0.1
        self.biases = np.zeros(self.filters)   
            
    def relu(self, x: np.ndarray) -> np.ndarray: #hàm kích hoạt relu
        return np.maximum(0, x)
    
    def forward(self, input_data: np.ndarray) -> np.ndarray:
        if self.kernels is None or self.biases is None:
            self.initialize_weights(input_data.shape[1:])  # Khởi tạo trọng số nếu cần
            
        self.input = input_data
        batch_size, height, width, channels = input_data.shape
        k_h, k_w = self.kernel_size
        
        #padding =0, stride =1
        out_h = height - k_h + 1
        out_w = width - k_w + 1
        
        output = np.zeros((batch_size, out_h, out_w, self.filters))
        
        for i in range(out_h):
            for j in range(out_w):
                patch = input_data[:, i:i+k_h, j:j+k_w, :] #lấy từng patch nhỏ từ đầu vào
                for f in range(self.filters):
                    output[:, i, j, f] = np.sum(patch * self.kernels[f], axis=(1,2,3)) + self.biases[f] #Từng patch của ảnh đầu vào được nhân với kernel (bộ lọc) tương ứng, sau đó cộng thêm bias và áp dụng hàm ReLU
                    
        return self.relu(output)

class MaxPool2D(Layer):
    def __init__(self, pool_size: Tuple[int, int] = (2, 2)):
        self.pool_size = pool_size
        
    def forward(self, input_data: np.ndarray) -> np.ndarray:
        self.input = input_data #lưu đầu vào để dùng trong truyền ngược
        batch_size, height, width, channels = input_data.shape
        p_h, p_w = self.pool_size
        
        out_h = height // p_h
        out_w = width // p_w
        
        output = np.zeros((batch_size, out_h, out_w, channels)) #mảng lưu kết quả
        
        for i in range(out_h):
            for j in range(out_w):
                patch = input_data[:, i*p_h:(i+1)*p_h, j*p_w:(j+1)*p_w, :] #lấy từng patch nhỏ
                output[:, i, j, :] = np.max(patch, axis=(1, 2)) #lấy max trong patch
                
        return output

#làm phẳng (flatten) dữ liệu đầu vào thành vector 1 chiều
class Flatten(Layer):
    def forward(self, input_data: np.ndarray) -> np.ndarray:
        self.input_shape = input_data.shape #lưu hình dạng để khôi phục khi cần
        return input_data.reshape(input_data.shape[0], -1) #làm phẳng

class Dense(Layer): #lớp fully connected
    def __init__(self, units: int, input_dim: int = None):
        self.units = units #số lượng neuron trong lớp 
        self.input_dim = input_dim #số chiều đầu vào
        self.weights = None  #khởi tạo khi cần
        self.biases = None
        
        
    def relu(self, x: np.ndarray) -> np.ndarray:
        return np.maximum(0, x)
    
    def sigmoid(self, x: np.ndarray) -> np.ndarray:
        return 1 / (1 + np.exp(-np.clip(x, -500, 500)))
        
    def forward(self, input_data: np.ndarray, activation: str = 'relu') -> np.ndarray:
        self.input = input_data
         
         #khởi tạo trọng số và bias nếu chưa được khởi tạo
        if self.weights is None:
            self.input_dim = input_data.shape[1]  # Set input_dim if it's not provided
            self.weights = np.random.randn(self.input_dim, self.units) * 0.1 #ma trận trọng số kết nối giữa các neuron
            self.biases = np.zeros(self.units)
        
        output = np.dot(input_data, self.weights) + self.biases #tính đầu ra
        
        #áp dụng hàm kích hoạt
        if activation == 'relu':
            return self.relu(output)
        elif activation == 'sigmoid':
            return self.sigmoid(output)
        return output

# %%
class Sequential:
    def __init__(self): #khởi tạo
        self.layers = []
        self.optimizer = None
        self.loss_fn = None
        self.metrics = {}
    
    def add(self, layer):
        #Thêm một lớp vào mô hình
        self.layers.append(layer)
    
    def compile(self, optimizer: str = 'adam', loss: str = 'binary_crossentropy', metrics: List[str] = None):
        #Cấu hình mô hình với trình tối ưu hóa, hàm mất mát và các metric
        if optimizer == 'adam':
            self.optimizer = Adam(learning_rate=0.1)
        self.loss_fn = self.binary_crossentropy if loss == 'binary_crossentropy' else None
        self.metrics = {metric: [] for metric in (metrics or [])}#khởi tạo các chỉ số
    
    def binary_crossentropy(self, y_true: np.ndarray, y_pred: np.ndarray) -> float:
        #Hàm mất mát Binary Crossentropy
        y_pred = np.clip(y_pred, 1e-7, 1 - 1e-7)# tránh log(0)
        return -np.mean(y_true * np.log(y_pred) + (1 - y_true) * np.log(1 - y_pred))
    
    def calculate_metrics(self, y_true: np.ndarray, y_pred: np.ndarray) -> Dict[str, float]:
        """Tính các giá trị metric."""
        metrics = {}
        for metric in self.metrics:
            if metric == 'accuracy': #tỉ lệ dự đoán đúng
                metrics[metric] = np.mean((y_pred > 0.5) == y_true)
            elif metric == 'recall': #tỉ lệ dự đoán đúng trên tổng số mẫu dương thực tế
                tp = np.sum((y_pred > 0.5) & (y_true == 1))
                fn = np.sum((y_pred <= 0.5) & (y_true == 1))
                metrics[metric] = tp / (tp + fn + 1e-7)
        return metrics
    
    def predict(self, X: np.ndarray) -> np.ndarray:
        #Dự đoán kết quả đầu ra với dữ liệu đầu vào
        output = X
        for layer in self.layers:
            output = layer.forward(output) #truyền dữ liệu qua từng lớp
        return output
    
    
    #huấn luyện mô hình
    def fit(self, 
            X_train: np.ndarray,
            y_train: np.ndarray,
            X_val: Optional[np.ndarray] = None,
            y_val: Optional[np.ndarray] = None,
            batch_size: int = 32,
            epochs: int = 5,
            callbacks: Optional[List] = None):
        
        
        """Hàm huấn luyện mô hình."""
        history = {'loss': [], 'val_loss': []}
        history.update({f'val_{m}': [] for m in self.metrics})

        num_train_samples = len(X_train) #kích thước tập train
        num_batches = int(np.ceil(num_train_samples / batch_size)) #tính số bacth trong mỗi epoch(làm tròn lên)
        
        for epoch in range(epochs):
            print(f'Epoch {epoch + 1}/{epochs}')
            epoch_loss = 0
            #lưu trữ các giá trị của các chỉ số (metrics) cho mỗi batch trong epoch
            batch_metrics = {metric: [] for metric in self.metrics}
            
            # Training
            for batch_index in range(num_batches):
                start = batch_index * batch_size
                end = min(start + batch_size, num_train_samples)
                batch_x = X_train[start:end] #batch đầu vào
                batch_y = y_train[start:end]# nhãn tương ứng
                
                # Forward pass
                output = self.predict(batch_x) #dự đoán cho mô hình từ batch hiên tại
                
                # Calculate loss(tính toán mất mát giữa nhãn thực tế- batch_y và output-dự đoán)
                loss = self.loss_fn(batch_y, output)
                epoch_loss += loss #cộng dồn vào epoch_loss
                
                # Calculate metrics- tính toán các chỉ số như độ chính xác, độ chính xác từng lớp
                batch_metric_values = self.calculate_metrics(batch_y, output)
                for metric, value in batch_metric_values.items():
                    batch_metrics[metric].append(value)
                  
                            
                
                
                # Cập nhật trọng số các layer
            
            # Epoch metrics
            epoch_loss /= num_batches #tính mất mát trung bình trong epoch
            epoch_metrics = {metric: np.mean(values) for metric, values in batch_metrics.items()}
            history['loss'].append(epoch_loss)
            for metric, value in epoch_metrics.items(): #Tính toán trung bình của các chỉ số cho toàn bộ epoch
                history[metric].append(value)
            
            # Validation - kiểm tra mô hình trên tập kiểm tra
            if X_val is not None and y_val is not None:
                val_loss = 0
                val_metrics = {metric: [] for metric in self.metrics}
                num_val_batches = int(np.ceil(len(X_val) / batch_size)) #số batch trong tập ktra
                
                #tính toán tương tự như trong tập train
                for batch_index in range(num_val_batches):
                    start = batch_index * batch_size
                    end = min(start + batch_size, len(X_val))
                    val_x = X_val[start:end]
                    val_y = y_val[start:end]
                    
                    val_pred = self.predict(val_x)
                    val_loss += self.loss_fn(val_y, val_pred)
                    
                    val_metric_values = self.calculate_metrics(val_y, val_pred)
                    for metric, value in val_metric_values.items():
                        val_metrics[metric].append(value)
                
                val_loss /= num_val_batches #tính mất mát trung bình
                val_metrics = {metric: np.mean(values) for metric, values in val_metrics.items()} #tbinh các chỉ số
                history['val_loss'].append(val_loss) #lưu vào history
                for metric, value in val_metrics.items():
                    history[f'val_{metric}'].append(value)
            
            # Print progress - in ra tiến độ huấn luyện
            progress_str = f"loss: {epoch_loss:.4f}"
            for metric, value in epoch_metrics.items():
                progress_str += f" - {metric}: {value:.4f}"
            if X_val is not None and y_val is not None:
                progress_str += f" - val_loss: {val_loss:.4f}"
                for metric, value in val_metrics.items():
                    progress_str += f" - val_{metric}: {value:.4f}"
            print(progress_str)
        
        return history


    #tính toán số parameter sau mỗi layer
    def summary(self, input_shape: Tuple[int, int, int]):
        print("=" * 70)
        print(f"{'Layer (type)':<30} {'Output Shape':<25} {'Param #':<10}")
        print("=" * 70)

        output_shape = input_shape
        total_params = 0

        for layer in self.layers: #duyệt qua từng lớp
            layer_type = layer.__class__.__name__
            if isinstance(layer, Conv2D): #kiểm tra có phải lớp conv2D ko
                k_h, k_w = layer.kernel_size#Lấy kích thước kernel của lớp này
                filters = layer.filters# Lấy số lượng filters (kênh đầu ra) của lớp Conv2D.
                
                
                # nếu lớp Conv2D không có thuộc tính input_shape hoặc thuộc tính này là None,
                # ta tính toán số lượng kênh đầu vào từ output_shape[-1] (chiều sâu của đầu ra từ lớp trước đó)
                if not hasattr(layer, "input_shape") or layer.input_shape is None:
                    input_channels = output_shape[-1]
                    layer.input_shape = (output_shape[0], output_shape[1], input_channels)
                    layer.initialize_weights(layer.input_shape) #khởi tạo trọng số
                else:
                    input_channels = layer.input_shape[-1]
                
                #tính toán lại output_shape
                output_shape = (
                    output_shape[0] - k_h + 1,#chiều cao đầu ra
                    output_shape[1] - k_w + 1,#chiều rộng đầu ra
                    filters #số kênh đầu ra
                )
                params = (k_h * k_w * input_channels + 1) * filters #tính số tham số
            elif isinstance(layer, MaxPool2D):
                p_h, p_w = layer.pool_size
                output_shape = (
                    output_shape[0] // p_h, #chiều cao
                    output_shape[1] // p_w, #chiều rộng
                    output_shape[-1]
                )
                params = 0 #không có tham số học
                
            elif isinstance(layer, Flatten):
                params = 0 #không có tham số học
                output_shape = (np.prod(output_shape),) #tính toán tổng số phần tử
                
                
            elif isinstance(layer, Dense):
                if hasattr(layer, "weights") and layer.weights is not None:
                    input_dim = layer.weights.shape[0] #Nếu lớp đã có trọng số (weights),
                    #ta lấy kích thước của đầu vào (input_dim) từ trọng số
                else: #Nếu lớp chưa có trọng số, ta tính input_dim từ output_shape[0] (số lượng đầu vào từ lớp trước)
                    input_dim = output_shape[0]
                    layer.weights = np.random.randn(input_dim, layer.units) * 0.1 #khởi tạo trọng số
                    layer.biases = np.zeros(layer.units) #khởi tạo bias
                params = input_dim * layer.units + layer.units
                output_shape = (layer.units,)
            else:
                params = 0

            total_params += params
            print(f"{layer_type:<30} {str(output_shape):<25} {params:<10}")
        
        print("=" * 70)
        print(f"Total params: {total_params}")
        print("=" * 70)
     
     
    def plot_metrics(self, history: dict):
        
        plt.figure(figsize=(12, 6))
        
        # Vẽ đồ thị loss
        plt.subplot(1, 2, 1)
        plt.plot(history['loss'], label='Training loss')
        if 'val_loss' in history:
            plt.plot(history['val_loss'], label='Validation loss')
        plt.title('Loss over epochs')
        plt.xlabel('Epochs')
        plt.ylabel('Loss')
        plt.legend()
        
        # Vẽ đồ thị accuracy 
        if 'accuracy' in history:
            plt.subplot(1, 2, 2)
            plt.plot(history['accuracy'], label='Training accuracy')
            if 'val_accuracy' in history:
                plt.plot(history['val_accuracy'], label='Validation accuracy')
            plt.title('Accuracy over epochs')
            plt.xlabel('Epochs')
            plt.ylabel('Accuracy')
            plt.legend()
        
        plt.tight_layout()
        plt.show()  
        
      #Hiển thị Confusion Matrix
      
    def plot_confusion_matrix(self, y_true: np.ndarray, y_pred: np.ndarray, labels: list = None):
       
        cm = confusion_matrix(y_true, y_pred)  # Tính toán confusion matrix từ y_true và y_pred
        
        plt.figure(figsize=(8, 6))
        sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=labels, yticklabels=labels)
        plt.title('Confusion Matrix')
        plt.xlabel('Predicted')
        plt.ylabel('True')
        plt.show()

# %%
#Xây dựng các layer
model = Sequential()
model.add(Conv2D(filters=8, kernel_size=(2,2), input_shape=(128,128,3)))
model.add(MaxPool2D())
model.add(Conv2D(filters=16, kernel_size=(2,2)))
model.add(MaxPool2D())
model.add(Conv2D(filters=32, kernel_size=(2,2)))
model.add(MaxPool2D())
model.add(Flatten())
model.add(Dense(16))  
model.add(Dense(18))  
model.add(Dense(1))   
model.summary(input_shape=(128, 128, 3))
# Out:
# ...
# Layer (type)                   Output Shape              Param #
# ...
# Conv2D                         (127, 127, 8)             104
# MaxPool2D                      (63, 63, 8)               0
# Conv2D                         (62, 62, 16)              528
# MaxPool2D                      (31, 31, 16)              0
# Conv2D                         (30, 30, 32)              2080
# MaxPool2D                      (15, 15, 32)              0
# Flatten                        (7200,)                   0
# Dense                          (16,)                     115216
# Dense                          (18,)                     306
# Dense                          (1,)                      19
# ...
# Total params: 118253
# ...

# %% [markdown]
# CALLBACKS

# %%
#Tạo các hàm dừng sớm khi cần

class EarlyStopping: #dừng huấn luyện nếu mô hình không cải thiện sau 5 epoch
    def __init__(self, monitor: str = 'val_loss', patience: int = 5, restore_best_weights: bool = True):
        self.monitor = monitor #thông số cần theo dõi
        self.patience = patience #số lượng epoch ngưỡng
        self.restore_best_weights = restore_best_weights #có khôi phục trọng số tốt nhất hay ko
        self.best_weights = None #lưu trọng số tốt nhất
        self.best_value = float('inf')# giá trị tốt nhất của thông số đang theo dõi
        self.counter = 0 #đếm số epoch ko cải thiện
        
    def __call__(self, model, value: float) -> bool:
        if value < self.best_value: # Nếu giá trị hiện tại tốt hơn giá trị tốt nhất trước đó
            self.best_value = value
            self.counter = 0  # Đặt lại bộ đếm
            if self.restore_best_weights: # Nếu được yêu cầu, lưu lại trọng số tốt nhất
                self.best_weights = model.get_weights()
        else:
            self.counter += 1 # Tăng bộ đếm nếu không cải thiện
            if self.counter >= self.patience: # Nếu quá số lượng patience
                if self.restore_best_weights and self.best_weights is not None:
                    model.set_weights(self.best_weights) # Khôi phục trọng số tốt nhất
                return True #dừng huấn luyện
        return False

class ReduceLROnPlateau: #giảm tốc độ học sau 1 số epoch(tương tự như hàm trên)
    def __init__(self, monitor: str = 'val_loss', factor: float = 0.1, patience: int = 5):
        self.monitor = monitor
        self.factor = factor
        self.patience = patience
        self.best_value = float('inf')
        self.counter = 0
        
    def __call__(self, optimizer, value: float) -> None:
        if value < self.best_value:
            self.best_value = value
            self.counter = 0
        else:
            self.counter += 1
            if self.counter >= self.patience:
                optimizer.learning_rate *= self.factor
                self.counter = 0

# %% [markdown]
# MODEL FITTING

# %%
from tensorflow.keras.optimizers import Adam #điều chỉnh trọng số mô hình sao cho loss giảm xuống 
model = Sequential()
model.add(Conv2D(filters=16, kernel_size=(2,2), input_shape=(128,128,3)))
model.add(MaxPool2D())
model.add(Conv2D(filters=32, kernel_size=(2,2)))
model.add(MaxPool2D())
model.add(Conv2D(filters=64, kernel_size=(2,2)))
model.add(MaxPool2D())
model.add(Flatten())
model.add(Dense(32))  
model.add(Dense(16))  
model.add(Dense(1))   

model.compile(
    optimizer='adam', 
    loss='binary_crossentropy',  #hàm mất mát cho btoan phân loại nhị phân
    metrics=['accuracy']  #sử dụng độ chính xác để đo hiệu suất mô hình
)

early_stopping = EarlyStopping(monitor='val_loss', patience=5)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=5)

# Train model
history = model.fit(
    X_train = X_train,
    y_train = y_train,
    X_val = X_val,
    y_val = y_val,
    batch_size = 32,
    epochs=10,
    callbacks=[early_stopping, reduce_lr]
)

# %% [markdown]
# HIỂN THỊ BIỂU ĐỒ METRIC

# %%
model.plot_metrics(history)

# %% [markdown]
# CONFUSION MATRIX

# %%
# Dự đoán trên tập kiểm tra (validation set)
y_pred = model.predict(X_val)

# Áp dụng ngưỡng 0.5 (vì là bài toán nhị phân)
y_pred_class = (y_pred > 0.5).astype(int)

# Vẽ confusion matrix
model.plot_confusion_matrix(y_val, y_pred_class, labels=['Class 0', 'Class 1'])
